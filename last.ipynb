# %%
import pandas as pd
import sqlite3
import seaborn as sns
import matplotlib.pyplot as plt

# %%
conn = sqlite3.connect('last.pylast.sqlite')

# %%
data1 =pd.read_sql_query('select*from bmr',conn)

# %%
data1
# Out:
#     day  avg_gr_hpa  avg_sea_hpa  low_sea_hpa  avg_temp  high_temp  low_temp  \
# 0     1      1012.3       1015.2       1013.0       8.7       12.6       6.4
# 1     2      1015.6       1018.5       1015.3       8.3       13.1       4.1
# 2     3      1015.5       1018.5       1013.9       9.1       15.2       4.1
# 3     4      1018.2       1021.2       1019.7       8.7       14.3       4.7
# 4     5      1016.3       1019.3       1013.9       8.1       10.3       5.7
# 5     6      1008.8       1011.8       1009.2      11.4       16.4       7.1
# 6     7      1004.1       1006.9       1000.0      12.9       19.9       7.1
# 7     8      1016.3       1019.2       1014.9      12.3       17.8       6.0
# 8     9      1017.0       1019.9       1017.7      11.9       17.2       6.4
# 9    10      1018.5       1021.4       1019.7      13.0       19.7       7.2
# 10   11      1019.6       1022.5       1017.9      13.4       16.0      11.3
# 11   12      1007.6       1010.5       1004.8      11.9       15.4       9.7
# 12   13      1021.2       1024.1       1016.0      10.8       15.1       7.3
# 13   14      1024.3       1027.2       1025.1      10.2       14.1       6.5
# 14   15      1011.8       1014.8       1004.2      11.0       20.2       7.1
# 15   16      1001.4       1004.2       1001.6      17.0       21.1      10.8
# 16   17      1007.5       1010.4       1000.9      11.2       17.2       5.9
# 17   18      1020.5       1023.5       1019.4       7.0       11.5       3.8
# 18   19      1020.2       1023.2       1018.0       7.0       10.6       3.4
# 19   20      1008.7       1011.6       1008.2       8.5       13.5       4.6
# 20   21      1008.3       1011.3       1008.1       7.7       13.1       3.3
# 21   22      1015.0       1018.0       1014.6       5.3       10.1       1.5
# 22   23      1023.8       1026.9       1023.4       5.0       10.6       0.1
# 23   24      1023.9       1027.0       1022.4       4.9        8.8       2.0
# 24   25      1018.2       1021.2       1018.2       6.3       12.1       1.0
# 25   26      1019.2       1022.2       1019.9       7.6       13.2       2.6
# 26   27      1022.5       1025.5       1020.8       8.4       12.6       4.3
# 27   28      1022.6       1025.6       1021.5       7.0       10.8       4.4
# 28   29      1018.2       1021.2       1019.8       7.8       13.8       2.2
# 29   30      1017.3       1020.3       1015.7       9.0       14.4       4.4
# 30   31      1004.0       1006.9       1001.9       9.2       12.7       5.8
#
#       vp  avg_hum  low_hum   bmr
# 0    6.0       54     37.0  1494
# 1    6.4       60     37.0  1460
# 2    6.6       58     36.0  1462
# 3    5.9       53     31.0  1455
# 4    6.8       64     53.0  1476
# 5   10.3       77     48.0  1475
# 6    8.7       60     30.0  1466
# 7    7.2       49     32.0  1482
# 8    9.2       66     49.0  1463
# 9    9.6       65     41.0  1485
# 10  11.3       74     61.0  1462
# 11  12.8       92     65.0  1472
# 12   6.6       52     27.0  1355
# 13   7.7       62     44.0  1270
# 14  10.9       82     65.0  1277
# 15  13.9       71     51.0  1289
# 16   5.1       36     20.0  1274
# 17   3.6       36     23.0  1268
# 18   5.4       53     35.0  1276
# 19   6.5       59     39.0  1274
# 20   4.2       41     21.0  1272
# 21   3.4       38     24.0  1282
# 22   4.0       47     24.0  1271
# 23   4.7       55     41.0  1274
# 24   5.2       56     35.0  1288
# 25   6.0       58     33.0  1272
# 26   5.4       50     39.0  1276
# 27   5.6       56     41.0  1274
# 28   6.3       61     37.0  1269
# 29   7.2       63     40.0  1268
# 30   9.2       79     62.0  1268

# %%
df = pd.DataFrame(data1)

# %%
df.describe()
# Out:
#              day   avg_gr_hpa  avg_sea_hpa  low_sea_hpa   avg_temp  high_temp  \
# count  31.000000    31.000000    31.000000    31.000000  31.000000  31.000000
# mean   16.000000  1015.432258  1018.387097  1014.183871   9.374194  14.303226
# std     9.092121     6.373036     6.415229     7.209766   2.770315   3.215430
# min     1.000000  1001.400000  1004.200000  1000.000000   4.900000   8.800000
# 25%     8.500000  1010.300000  1013.300000  1008.700000   7.650000  12.350000
# 50%    16.000000  1017.000000  1019.900000  1015.700000   8.700000  13.800000
# 75%    23.500000  1019.900000  1022.850000  1019.700000  11.300000  16.200000
# max    31.000000  1024.300000  1027.200000  1025.100000  17.000000  21.100000
#
#         low_temp         vp    avg_hum    low_hum          bmr
# count  31.000000  31.000000  31.000000  31.000000    31.000000
# mean    5.187097   7.151613  58.935484  39.387097  1353.193548
# std     2.656030   2.647498  13.142642  12.566297    96.614843
# min     0.100000   3.400000  36.000000  20.000000  1268.000000
# 25%     3.600000   5.400000  52.500000  31.500000  1273.000000
# 50%     4.700000   6.500000  58.000000  37.000000  1282.000000
# 75%     6.800000   8.950000  64.500000  46.000000  1462.500000
# max    11.300000  13.900000  92.000000  65.000000  1494.000000

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df.hist(bins=100, color = "blue", grid =True, label = 'pandas') # ヒストグラム導出
plt.ylim(0,50)
plt.ylabel('frequency')
plt.xlabel('index')
plt.show()
plt.close()

# %%
df.corr() # 各変数の相関を出す
# Out:
#                   day  avg_gr_hpa  avg_sea_hpa  low_sea_hpa  avg_temp  \
# day          1.000000    0.176433     0.179673     0.157280 -0.433407
# avg_gr_hpa   0.176433    1.000000     0.999958     0.954480 -0.513715
# avg_sea_hpa  0.179673    0.999958     1.000000     0.954384 -0.519351
# low_sea_hpa  0.157280    0.954480     0.954384     1.000000 -0.508617
# avg_temp    -0.433407   -0.513715    -0.519351    -0.508617  1.000000
# high_temp   -0.384242   -0.510626    -0.514823    -0.526602  0.903792
# low_temp    -0.465721   -0.441184    -0.446553    -0.468156  0.900737
# vp          -0.290940   -0.495165    -0.498577    -0.475109  0.845519
# avg_hum     -0.147008   -0.334507    -0.335585    -0.317566  0.501016
# low_hum     -0.081981   -0.230998    -0.231942    -0.241356  0.424281
# bmr         -0.865290   -0.154662    -0.157835    -0.101866  0.449282
#
#              high_temp  low_temp        vp   avg_hum   low_hum       bmr
# day          -0.384242 -0.465721 -0.290940 -0.147008 -0.081981 -0.865290
# avg_gr_hpa   -0.510626 -0.441184 -0.495165 -0.334507 -0.230998 -0.154662
# avg_sea_hpa  -0.514823 -0.446553 -0.498577 -0.335585 -0.231942 -0.157835
# low_sea_hpa  -0.526602 -0.468156 -0.475109 -0.317566 -0.241356 -0.101866
# avg_temp      0.903792  0.900737  0.845519  0.501016  0.424281  0.449282
# high_temp     1.000000  0.695923  0.726999  0.408121  0.270225  0.360566
# low_temp      0.695923  1.000000  0.854451  0.600997  0.598880  0.481165
# vp            0.726999  0.854451  1.000000  0.867174  0.792504  0.388303
# avg_hum       0.408121  0.600997  0.867174  1.000000  0.923535  0.318728
# low_hum       0.270225  0.598880  0.792504  0.923535  1.000000  0.230946
# bmr           0.360566  0.481165  0.388303  0.318728  0.230946  1.000000

# %%
sns.set_style("darkgrid")

sns.regplot(x=df['bmr'],y=df['vp'])
# Out:
# <Axes: xlabel='bmr', ylabel='vp'>

# %%
sns.heatmap(df.corr(), annot=True)

print(df.corr())
# Out:
#                   day  avg_gr_hpa  avg_sea_hpa  low_sea_hpa  avg_temp  \
# day          1.000000    0.176433     0.179673     0.157280 -0.433407
# avg_gr_hpa   0.176433    1.000000     0.999958     0.954480 -0.513715
# avg_sea_hpa  0.179673    0.999958     1.000000     0.954384 -0.519351
# low_sea_hpa  0.157280    0.954480     0.954384     1.000000 -0.508617
# avg_temp    -0.433407   -0.513715    -0.519351    -0.508617  1.000000
# high_temp   -0.384242   -0.510626    -0.514823    -0.526602  0.903792
# low_temp    -0.465721   -0.441184    -0.446553    -0.468156  0.900737
# vp          -0.290940   -0.495165    -0.498577    -0.475109  0.845519
# avg_hum     -0.147008   -0.334507    -0.335585    -0.317566  0.501016
# low_hum     -0.081981   -0.230998    -0.231942    -0.241356  0.424281
# bmr         -0.865290   -0.154662    -0.157835    -0.101866  0.449282
#
#              high_temp  low_temp        vp   avg_hum   low_hum       bmr
# day          -0.384242 -0.465721 -0.290940 -0.147008 -0.081981 -0.865290
# avg_gr_hpa   -0.510626 -0.441184 -0.495165 -0.334507 -0.230998 -0.154662
# avg_sea_hpa  -0.514823 -0.446553 -0.498577 -0.335585 -0.231942 -0.157835
# low_sea_hpa  -0.526602 -0.468156 -0.475109 -0.317566 -0.241356 -0.101866
# avg_temp      0.903792  0.900737  0.845519  0.501016  0.424281  0.449282
# high_temp     1.000000  0.695923  0.726999  0.408121  0.270225  0.360566
# low_temp      0.695923  1.000000  0.854451  0.600997  0.598880  0.481165
# vp            0.726999  0.854451  1.000000  0.867174  0.792504  0.388303
# avg_hum       0.408121  0.600997  0.867174  1.000000  0.923535  0.318728
# low_hum       0.270225  0.598880  0.792504  0.923535  1.000000  0.230946
# bmr           0.360566  0.481165  0.388303  0.318728  0.230946  1.000000

# %%
plt.hist(data1, bins=10) 
plt.title('Histogram')
plt.xlabel('Values')
plt.ylabel('Frequency')

plt.show()
